# %%
#using pillow,matplotlib,opencv
import matplotlib.image as matimg
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#cv2 reads in numpy and pillow using rgb object
img_cv=cv2.imread('flying_bird.jpg')#bgr
img_mat=matimg.imread('flying_bird.jpg')#rgb
img_pil=Image.open('flying_bird.jpg')#rgb
#print(img_cv)# one tuple forms a color
#print(img_mat)
#print(img_pil.size)

# %%
#convert pil object to arr
img_pil_arr=np.array(img_pil)
print(img_pil_arr.dtype)
# Out:
# uint8

# %% [markdown]
# # **DISPLAY IMAGE**

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img_cv)
# for jupyter cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
plt.imshow(img_cv)
plt.axis('off')
plt.show()

# %%
from google.colab.patches import cv2_imshow
plt.subplot(1,2,1)
plt.title('opencv_image')
plt.imshow(img_cv)
plt.axis('off')
plt.subplot(1,2,2)
plt.axis('off')
plt.title('omatplotlib_image')
plt.imshow(img_mat)
